# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# # Week 1 Research Question
#
# ## My Lane
#
# I selected the **Google Search Ranking & Discoverability** lane because improving search performance helps websites gain more visibility and attract users. This lane also provides measurable metrics such as impressions, clicks, CTR, and average position, making it suitable for machine learning analysis.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
#
# **Question**
#
# Can we identify pages that are likely to receive a low Click-Through Rate (CTR) based on search performance metrics?
#
# **Decision**
#
# Identify pages that may require SEO improvements.
# M
# **Action**
#
# Prioritize low-performing pages for optimization, such as improving titles, descriptions, and content quality.
#
# **Cost of a Wrong Recommendation**
#
# If the recommendation is incorrect, time and resources may be spent optimizing pages that do not actually need improvement, while truly important pages may be ignored.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
from pathlib import Path

# Find the starter CSV automatically
csv_files = list(Path(".").rglob("*.csv"))

print(csv_files)
# Out:
# [PosixPath('sample_data/mnist_train_small.csv'), PosixPath('sample_data/california_housing_train.csv'), PosixPath('sample_data/california_housing_test.csv'), PosixPath('sample_data/mnist_test.csv')]

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ### What I can and can't claim
#
# This project can identify observed patterns in the dataset and provide decision support for improving search performance. The model may help prioritize pages that need attention based on measurable metrics such as impressions, CTR, and average position.
#
# However, this project cannot prove why Google ranks pages in a certain way or establish a cause-and-effect relationship. The results are based only on the available dataset and should be validated with additional testing before making important business decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
